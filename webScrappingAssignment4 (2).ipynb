# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# Q2.
# Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage of BCCI
url = "https://www.bcci.tv/"
driver.get(url)

# %%
international_button = driver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[2]/nav/ul/li[1]/div[2]')       # Locating international_button by xpath
international_button.click()  # Clicking the button to view drop-down

# %%
fixers = driver.find_element_by_xpath('//a[@class="navigation__link navigation__link--in-drop-down"]')
url = fixers.get_attribute("href")
driver.get(url) # navigating to inetrnational fixtures page

# %%
match_title=[]
match_series=[]
place=[]
date=[]
time=[]

loc = driver.find_elements_by_xpath('//p[@class="fixture__additional-info"]//span')
for i in loc:
    place.append(i.text)
    
ser = driver.find_elements_by_xpath('//div[@class="fixture__description u-unskewed-text"]//p/strong')
for k in ser:
    match_title.append(k.text)

t = driver.find_elements_by_xpath('//span[@class="fixture__time"]')
for j in t:
    time.append(j.text)
    
s = driver.find_element_by_xpath('//span[@class="u-unskewed-text fixture__tournament-label u-truncated"]')
match_series.append(s.text)
 
p = driver.find_elements_by_xpath('//div[@class="fixture__full-date"]/span')
p2 =  driver.find_elements_by_xpath('//div[@class="fixture__full-date"]/div')
d1=[]
d2=[]
for j in p:
    d1.append(j.text)


for k in p2:
    d2.append(k.text.split('\n')[0])


for i in range(len(d1)):
    date.append(d1[i]+' '+d2[i])



# t = driver.find_elements_by_xpath('//div[@class="fixture__full-date"]')
# for j in t:
#     print(j.text)

# %%
import pandas as pd
 # creating the dataframe from the scraped data 

print(len(match_series),len(match_title),len(place),len(date),len(time))
df=pd.DataFrame({"Match Title":match_title,"Match Series":match_series,"Place":place,"date":date,"time":time})
df
# Out:
# 5 5 5 5 5
#   Match Title          Match Series                     Place          date  \
# 0    1st Test  ENGLAND V INDIA 2021  Trent Bridge, Nottingham     04 AUGUST
# 1    2nd Test  ENGLAND V INDIA 2021            Lord's, London     12 AUGUST
# 2    3rd Test  ENGLAND V INDIA 2021         Headingley, Leeds     25 AUGUST
# 3    4th Test  ENGLAND V INDIA 2021          The Oval, London  02 SEPTEMBER
# 4    5th Test  ENGLAND V INDIA 2021  Old Trafford, Manchester  10 SEPTEMBER
#
#         time
# 0  15:30 IST
# 1  15:30 IST
# 2  15:30 IST
# 3  15:30 IST
# 4  15:30 IST

# %% [markdown]
# Q3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage of BCCI
url = " https://www.guru99.com/"
driver.get(url)

# %%
sel_url = driver.find_element_by_xpath('/html/body/div[2]/section[4]/div/div/div/div/div/div/div/div[1]/div/ul[1]/li[3]/a')
url = sel_url.get_attribute("href")
print(url)
driver.get(url)
# Out:
# https://www.guru99.com/selenium-tutorial.html

# %%
sele_exp_link = driver.find_element_by_xpath('/html/body/div[2]/section[3]/div/div[1]/main/div/div/div/div/div/div/div[2]/table[5]/tbody/tr[34]/td[1]/a')
url = sele_exp_link.get_attribute("href")
print(url)
driver.get(url)
# Out:
# https://www.guru99.com/exception-handling-selenium.html

# %%
table = driver.find_elements_by_xpath('//table[@class="table table-striped"]')
exps=[]
exp=[]
descr=[]
for i in table:
    exps= i.text.split('\n')[1::]

for i in range(len(exps)):
    exp.append(exps[i].split(' ')[0])
exp
# Out:
# ['ElementNotVisibleException',
#  'ElementNotSelectableException',
#  'NoSuchElementException',
#  'NoSuchFrameException',
#  'NoAlertPresentException',
#  'NoSuchWindowException',
#  'StaleElementReferenceException',
#  'SessionNotFoundException',
#  'TimeoutException',
#  'WebDriverException',
#  'ConnectionClosedException',
#  'ElementClickInterceptedException',
#  'ElementNotInteractableException',
#  'ErrorInResponseException',
#  'ErrorHandler.UnknownServerException',
#  'ImeActivationFailedException',
#  'ImeNotAvailableException',
#  'InsecureCertificateException',
#  'InvalidArgumentException',
#  'InvalidCookieDomainException',
#  'InvalidCoordinatesException',
#  'InvalidElementStateExceptio',
#  'InvalidSessionIdException',
#  'InvalidSwitchToTargetException',
#  'JavascriptException',
#  'JsonException',
#  'NoSuchAttributeException',
#  'MoveTargetOutOfBoundsException',
#  'NoSuchContextException',
#  'NoSuchCookieException',
#  'NotFoundException',
# ...

# %%
exps
# Out:
# ['ElementNotVisibleException This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  'ElementNotSelectableException This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#  'NoSuchElementException This Exception occurs if an element could not be found.',
#  'NoSuchFrameException This Exception occurs if the frame target to be switched to does not exist.',
#  'NoAlertPresentException This Exception occurs when you switch to no presented alert.',
#  'NoSuchWindowException This Exception occurs if the window target to be switch does not exist.',
#  'StaleElementReferenceException This Selenium exception occurs happens when the web element is detached from the current DOM.',
#  'SessionNotFoundException The WebDriver is acting after you quit the browser.',
# ...

# %%
for i in range(len(exps)):
    descr.append(exps[i].partition(' ')[2])
descr
# Out:
# ['This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  'This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#  'This Exception occurs if an element could not be found.',
#  'This Exception occurs if the frame target to be switched to does not exist.',
#  'This Exception occurs when you switch to no presented alert.',
#  'This Exception occurs if the window target to be switch does not exist.',
#  'This Selenium exception occurs happens when the web element is detached from the current DOM.',
#  'The WebDriver is acting after you quit the browser.',
#  "Thrown when there is not enough time for a command to be completed. For Example, the element searched wasn't found in the specified time.",
#  'This Exception takes place when the WebDriver is acting right after you close the browser.',
# ...

# %%
print(len(descr),len(exp))
# Out:
# 41 41

# %%
df=pd.DataFrame({"Exception name":exp,"Description":descr})
df
# Out:
#                          Exception name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP at current price (19-20)
# D) GSDP at current price (18-19)
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage of BCCI
url = " http://statisticstimes.com/"
driver.get(url)

# %%
drp = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button')
drp.click()

# %%
ind_link = driver.find_elements_by_xpath('//div[@class="dropdown-content"]/a[3]')
for i in ind_link:
    url = i.get_attribute("href")
# navigating to india url
driver.get(url)

# %%
gdp_url = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
url = gdp_url.get_attribute("href")

# navigating to gdp page
driver.get(url)

# %%
# Obtain the number of rows in body
rows = 1+len(driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr'))
rows
# Out:
# 34

# %%
# Obtain the number of columns in body
cols = 1+len(driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr[1]/td'))
cols
# Out:
# 9

# %%
# Empty lists
gdp = {}
gdp['Rank'] = []
gdp['State'] = []
gdp['GSDP19'] = []
gdp['GSDP18'] = []
gdp['Share'] = []
gdp['GDP'] = []

# %%
try:
    # finding rank
    dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[1]')
    for d in dt:
        gdp['Rank'].append(d.text)
except NoSuchElementException:
    gdp['Rank'].append('-')
    
try:
    # finding state
    dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[2]')
    for d in dt:
        gdp['State'].append(d.text)
except NoSuchElementException:
    gdp['State'].append('-')
    
    
try:
    # finding GSDP(19-20)
    dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[3]')
    for d in dt:
        gdp['GSDP19'].append(d.text)
except NoSuchElementException:
    gdp['GSDP19'].append('-')
    
    
try:
    # finding GSDP(18-19)
    dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[4]')
    for d in dt:
        gdp['GSDP18'].append(d.text)
except NoSuchElementException:
    gdp['GSDP18'].append('-')
    
try:
    # finding share
    dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[5]')
    for d in dt:
        gdp['Share'].append(d.text)
except NoSuchElementException:
    gdp['Share'].append('-')
    
try:
    # finding gdp
    dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[6]')
    for d in dt:
        gdp['GDP'].append(d.text)
except NoSuchElementException:
    gdp['GDP'].append('-')

# %%
print(len(gdp['Rank']),len(gdp['State']),len(gdp['GSDP18']),len(gdp['GSDP19']),len(gdp['GDP']),len(gdp['Share']))
data = pd.DataFrame(gdp)
data
# Out:
# 33 33 33 33 33 33
#    Rank                      State     GSDP19     GSDP18   Share      GDP
# 0     1                Maharashtra          -  2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.39%  240.726
# 3     4                    Gujarat          -  1,502,899   7.96%  228.290
# 4     5                  Karnataka  1,631,977  1,493,127   7.91%  226.806
# 5     6                West Bengal  1,253,832  1,089,898   5.77%  165.556
# 6     7                  Rajasthan  1,020,989    942,586   4.99%  143.179
# 7     8             Andhra Pradesh    972,782    862,957   4.57%  131.083
# 8     9                  Telangana    969,604    861,031   4.56%  130.791
# 9    10             Madhya Pradesh    906,672    809,592   4.29%  122.977
# 10   11                     Kerala          -    781,653   4.14%  118.733
# ...

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage of BCCI
url = "https://github.com/"
driver.get(url)

# %%
explore_button = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
explore_button.click()

# %%
trending_button = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a')
url = trending_button.get_attribute("href")
print(url)

driver.get(url)
# Out:
# https://github.com/trending

# %%
git = {}
git['Repository title']=[]
git['Repository description']=[]
#git['Contributors count']=[]
git['Language used']=[]

# %%
try:
    repo=driver.find_elements_by_xpath('//h1[@class="h3 lh-condensed"]//a')
    for i in repo:
        git['Repository title'].append(i.text)
except NoSuchElementException:
    git['Repository title'].append('--')

# %%
try:
    desc=driver.find_elements_by_xpath('//p[@class="col-9 color-text-secondary my-1 pr-4"]')
    for i in desc:
        git['Repository description'].append(i.text)   
        
except NoSuchElementException:
    git['Repository description'].append('--')

# %%
try:
    desc=driver.find_elements_by_xpath('//span[@class="d-inline-block ml-0 mr-3"]//span')
    for i in desc:
        git['Language used'].append(i.text)   
        
except NoSuchElementException:
    git['Language used'].append('--')

# %%
desc=driver.find_elements_by_xpath('//span[@class="d-inline-block mr-3"]/a')
desc
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4c660c9e486561f1b4d5bc8121f34518", element="80f4338d-cdc8-493c-94db-4cff8aebf5c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c660c9e486561f1b4d5bc8121f34518", element="15c601cd-daac-4f69-b446-5622a5cff192")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c660c9e486561f1b4d5bc8121f34518", element="ebcf415c-d8ca-49bf-b7b3-2e45b27e00f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c660c9e486561f1b4d5bc8121f34518", element="98bf96f8-1432-44e8-a8b1-3614e8eb2cfd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c660c9e486561f1b4d5bc8121f34518", element="4dfdb9a2-6341-4cb6-b95a-216b5fc80ba9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c660c9e486561f1b4d5bc8121f34518", element="3f7e308a-557b-40dd-bcd3-21c2b9e3a181")>,
# ...

# %%
print(len(git['Language used']),len(git['Repository description']),len(git['Repository title']))
data = pd.DataFrame(git)
data
# Out:
# 44 24 25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-344-87e6a544caa2> in <module>
#       1 print(len(git['Language used']),len(git['Repository description']),len(git['Repository title']))
# ----> 2 data = pd.DataFrame(git)
#       3 data
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# ...

# %% [markdown]
# 6. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage of BCCI
url = " https://www.billboard.com/"
driver.get(url)

# %%
chart= driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/header/div/ul/li[1]/a')
chart.click()

# %%
h100= driver.find_element_by_xpath('/html/body/main/div[2]/div/div[1]/a/div[2]/div[2]/div[1]')
h100.click()

# %%
chart={}
chart['Song name']=[]
chart['Artist name']=[]
chart['Last week rank']=[]
chart['Peak rank']=[]
chart['Weeks on board']=[]

# %%
# song name
try:
    repo=driver.find_elements_by_xpath('//span[@class="chart-element__information__song text--truncate color--primary"]')
    for i in repo:
        chart['Song name'].append(i.text)
except NoSuchElementException:
    chart['Song name'].append('--')

# %%
# artist name
try:
    repo=driver.find_elements_by_xpath('//span[@class="chart-element__information__artist text--truncate color--secondary"]')
    for i in repo:
        chart['Artist name'].append(i.text)
except NoSuchElementException:
    chart['Artist name'].append('--')

# %%
# last week rank
try:
    repo=driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--last"]')
    for i in repo:
        chart['Last week rank'].append(i.text)
except NoSuchElementException:
    chart['Last week rank'].append('--')

# %%
# peak rank
try:
    repo=driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--peak"]')
    for i in repo:
        chart['Peak rank'].append(i.text)
except NoSuchElementException:
    chart['Peak rank'].append('--')

# %%
# Weeks on board
try:
    repo=driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--week"]')
    for i in repo:
        chart['Weeks on board'].append(i.text)
except NoSuchElementException:
    chart['Weeks on board'].append('--')

# %%
data = pd.DataFrame(chart)
data
# Out:
#           Song name                                        Artist name  \
# 0            Butter                                                BTS
# 1     Industry Baby                            Lil Nas X & Jack Harlow
# 2          Good 4 U                                     Olivia Rodrigo
# 3              Stay                      The Kid LAROI & Justin Bieber
# 4        Levitating                          Dua Lipa Featuring DaBaby
# ..              ...                                                ...
# 95     Minimum Wage                                      Blake Shelton
# 96          Working                                Tate McRae X Khalid
# 97      Holy Smokes                Trippie Redd Featuring Lil Uzi Vert
# 98        WUSYANAME  Tyler, The Creator Featuring YoungBoy Never Br...
# 99  Still Chose You                    The Kid LAROI Featuring Mustard
#
#    Last week rank Peak rank Weeks on board
# 0               1         1             10
# ...

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/"
driver.get(url)

# %%
book={}
book['Rank']=[]
book['Book name']=[]
book['Author name']=[]
book['Volumes sold']=[]
book['Publisher']=[]
book['Genre']=[]

# %%
try:
    # finding rank
    dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[1]')
    for d in dt:
        book['Rank'].append(d.text)
except NoSuchElementException:
    book['Rank'].append('-')
    
try:
    # finding Book name
    dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
    for d in dt:
        book['Book name'].append(d.text)
except NoSuchElementException:
    book['Book name'].append('-')
    
    
try:
    # finding Author name
    dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
    for d in dt:
        book['Author name'].append(d.text)
except NoSuchElementException:
    book['Author name'].append('-')
    
    
try:
    # finding Volumes sold
    dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
    for d in dt:
        book['Volumes sold'].append(d.text)
except NoSuchElementException:
    book['Volumes sold'].append('-')
    
try:
    # finding Publisher
    dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
    for d in dt:
        book['Publisher'].append(d.text)
except NoSuchElementException:
    book['Publisher'].append('-')
    
try:
    # finding Genre
    dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
    for d in dt:
        book['Genre'].append(d.text)
except NoSuchElementException:
    book['Genre'].append('-')

# %%
data = pd.DataFrame(book)
data
# Out:
#    Rank                                          Book name       Author name  \
# 0     1                                  Da Vinci Code,The        Brown, Dan
# 1     2               Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2     3           Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3     4          Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4     5                               Fifty Shades of Grey      James, E. L.
# ..  ...                                                ...               ...
# 95   96                                          Ghost,The    Harris, Robert
# 96   97                     Happy Days with the Naked Chef     Oliver, Jamie
# 97   98              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98   99  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  100  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
# ...

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage
url = " https://www.imdb.com/list/ls095964455/"
driver.get(url)

# %%
tv={}
tv['Name']=[]
tv['Year span']=[]
tv['Genre']=[]
tv['Run time']=[]
tv['Ratings']=[]
tv['Votes']=[]

# %%
try:
    
    dt = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]//a')
    for d in dt:
        tv['Name'].append(d.text)
except NoSuchElementException:
    tv['Name'].append('-')
    
try:
   
    dt = driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
    for d in dt:
        tv['Year span'].append(d.text)
except NoSuchElementException:
    tv['Year span'].append('-')
    
    
try:
   
    dt = driver.find_elements_by_xpath('//span[@class="genre"]')
    for d in dt:
        tv['Genre'].append(d.text)
except NoSuchElementException:
    tv['Genre'].append('-')
    
    
try:
    
    dt = driver.find_elements_by_xpath('//span[@class="runtime"]')
    for d in dt:
        tv['Run time'].append(d.text)
except NoSuchElementException:
    tv['Run time'].append('-')
    
try:
   
    dt = driver.find_elements_by_xpath('//span[@class="ipl-rating-star__rating"]')
    for d in dt:
        tv['Ratings'].append(d.text)
except NoSuchElementException:
    tv['Ratings'].append('-')
    
try:
    
    dt = driver.find_elements_by_xpath('//p[@class="text-muted text-small"]/span')
    for d in dt:
        tv['Votes'].append(d.text)
except NoSuchElementException:
    tv['Votes'].append('-')

# %%
data = pd.DataFrame(tv)
data
